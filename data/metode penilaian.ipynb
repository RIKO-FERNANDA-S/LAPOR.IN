# %%
pengguna = [
    "Arkan Pratama",
    "Kirana Larasati",
    "Bintang Ramadhan",
    "Aisyah Putri",
    "Reza Maulana",
    "Citra Kirana",
    "Dimas Saputra",
    "Dewi Sartika"
]

# %%
nilai_pengguna = [
    3,
    2,
    5,
    1,
    4,
    2,
    3,
    5
]

# %%
banyak_penilai = len(pengguna)
akumulasi_nilai_pengguna = sum(nilai_pengguna)

# %%
nilai_tempat = akumulasi_nilai_pengguna/banyak_penilai*20 # *20 untuk membuatnya per 100

# %%
print("Nilai tempat ini: ", nilai_tempat)
# Out:
# Nilai tempat ini:  62.5

# %%
tempat = ["Taman Apsari",
"Taman Bungkul",
"Perpustakaan Kota",
"Alun-alun",
"Jalan Darmo",
"Jalan Tunjungan",
"JPO Darmo",
"Halte Tunjungan"]

# %%
nilai_tempat = [7.410,
17.930,
28.660,
39.020,
51.270,
64.550,
82.140,
95.880]

# %%
banyak_tempat = len(tempat)
akumulasi_nilai_tempat = sum(nilai_tempat)

# %%
nilai_daerah = akumulasi_nilai_tempat/banyak_tempat

# %%
print("Nilai daerah: ", nilai_daerah)
# Out:
# Nilai daerah:  48.3575

# %%
def predikat(nilai:float):
    x = nilai
    y = ""
    if nilai >= 85:
        y = "Adibina"
    elif nilai >= 70:
        y = "Swabina"
    elif nilai >= 55:
        y = "Purwabina"
    elif nilai >= 40:
        y = "Rentanbina"
    elif nilai < 40:
        y = "Nirbina"

    return y

# %%
for x in [39, 40, 41, 54, 55, 56, 69.9, 70, 71, 84, 85, 86, 100]:
    print(x, predikat(x))
# Out:
# 39 Nirbina
# 40 Rentanbina
# 41 Rentanbina
# 54 Rentanbina
# 55 Purwabina
# 56 Purwabina
# 69.9 Purwabina
# 70 Swabina
# 71 Swabina
# 84 Swabina
# 85 Adibina
# 86 Adibina
# 100 Adibina
